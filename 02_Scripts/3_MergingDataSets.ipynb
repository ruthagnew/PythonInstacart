# %% [markdown]
# # Merging products and order dataframes
#
# Combining orders data set with new data, order_products_prior
#
# 1. Import libraries and data set
# 2. Removing unwanted indexes
# 3. Merging data set
# 4. Combine newly merged dataframe with products dataset
# 5. Exporting data frame

# %% [markdown]
# # 1. Import libraries and data set

# %%
#import libraries
import pandas as pd
import numpy as nm
import os

# %%
#folder path into usable string
path = r'C:\Users\rutha\CareerFoundry\01-23_Instacart_Basket_Analysis'

# %%
#import order_products_prior
df_ords_prior = pd.read_csv(os.path.join(path, '02_Data', 'Original_data', 'order_products_prior.csv'))

# %%
#check output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#import orders
df_ords = pd.read_csv(os.path.join(path, '02_Data', 'Prepared_data', 'orders_clean.csv'))

# %%
#checking output 
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
#import prods data set
df_prods = pd.read_csv(os.path.join(path, '02_Data', 'Prepared_data', 'products_clean.csv'),index_col=False)

# %%
#checking output
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
#dropping unnamed column
df_prods.drop(columns = ['Unnamed: 0'])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#defining df_ords without the eval_set column
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
#checking output
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # 2. Removing unwanted indexes

# %% [markdown]
# An unwanted column, *Unnamed: 0*, has appeared in the dataset so we will remove this before we conduct our analysis

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#removing column called 'Unnamed 0'
df_ords = df_ords.drop(['Unnamed: 0'],axis=1)

# %%
#checking output
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#checking shape
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#checking shape
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# # 3. Merging orders dataset with prior orders dataset

# %% [markdown]
# We are going to merge our clean dataset, orders, with a new dataset called *prior orders* which will give us information on the product id. Our join will be made on the shared variable, *order_id*.

# %%
#merging df_ords and df_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#checking output
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#checking output
df_merged_large.shape
# Out:
# (32434489, 10)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07        3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01        2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01        2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00        1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# **Observations**

# %% [markdown]
# Our new dataframe has the same number of rows as before, so the merge is successful.

# %% [markdown]
# # 4. Combine newly merged dataframe with products dataset

# %% [markdown]
# Merging with the products dataset will give us crucial information about the products purchased in each order. Using the merge() function on the common variable, 'product_id' will enable us to see any instances where the product_id doesn't match, as they would appear as NaN values.

# %%
#merging data sets
df_merged_final = df_merged_large.merge(df_prods, on = ['product_id'])

# %%
df_merged_final.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
#check output
df_merged_final['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# **Observations**

# %% [markdown]
# The dataset has the same number of rows, so the merge was successful.

# %% [markdown]
# # 5. Export data frame

# %%
#export new dataframe in pickle 
df_merged_final.to_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'full_merged.pkl'))
