# %% [markdown]
# # 4.8 Grouping Data and Aggregating Variables
#
# 1. Aggregating data with agg() function
# 2. Aggregating data with transform()
# 3. Deriving columns with loc()

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create usable path 
path = r'C:\Users\rutha\CareerFoundry\01-23_Instacart_Basket_Analysis'

# %%
#import dataframe
df = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'full_merged3.pkl'))

# %%
#dropping busiest day column
df = df.drop(['busiest_day'], axis = 1)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#      price_range_loc    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy        Average orders
# 2  Low-range product  Regularly busy        Average orders
# 3  Low-range product  Regularly busy        Average orders
# 4  Low-range product  Regularly busy        Average orders

# %% [markdown]
# Create a subset of the first one million entries in the dataframe

# %%
#create subset of first one million entries
df_subset = df[:1000000]

print('Sample output of subset filter of merged dataset:')
df_subset.sample(5)
# Out:
# Sample output of subset filter of merged dataset:
#         order_id  user_id  order_number  orders_day_of_week  \
# 784621   1804176     5168            27                   3
# 603219   2333242     4041            11                   4
# 43670    1169863      290            13                   6
# 80155    2324216      523             2                   5
# 369163   3378514     2446             4                   6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 784621                 18                     2.0       25659
# 603219                 10                    15.0      -24639
# 43670                  11                     7.0       16669
# 80155                  15                    16.0       21694
# 369163                 11                     7.0       22935
#
#         add_to_cart_order  reordered _merge  \
# 784621                  5          1   both
# 603219                  9          1   both
# 43670                   5          1   both
# 80155                   1          1   both
# 369163                 13          1   both
#
#                                        product_name  aisle_id  department_id  \
# 784621                         Organic Coconut Milk      91.0           16.0
# 603219                                         Kale     123.0            4.0
# 43670   Grilled Chicken Canine Cuisine Wet Dog Food      40.0            8.0
# 80155                        Mini Classic Ice Cream      37.0            1.0
# 369163                         Organic Yellow Onion      83.0            4.0
#
#         prices    price_range_loc    busiest_days busiest_period_of_day
# 784621     4.1  Low-range product    Slowest days        Average orders
# 603219     6.6  Mid-range product    Slowest days           Most orders
# 43670     14.0  Mid-range product  Regularly busy           Most orders
# 80155      8.9  Mid-range product  Regularly busy           Most orders
# 369163     1.4  Low-range product  Regularly busy           Most orders

# %%
df_subset.shape
# Out:
# (1000000, 17)

# %% [markdown]
# # 1. Grouping data with agg() function

# %%
#group your data by product name
df.groupby('product_name')

# %% [markdown]
# Calculating the mean of the 'order_number' grouped by 'department_id'

# %%
#split the data into groups based on dep_id, then agg() by ord_number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %%
#using the mean() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.457838
# 2.0     17.277920
# 3.0     17.170395
# 4.0     17.811403
# 5.0     15.215751
# 6.0     16.439806
# 7.0     17.225802
# 8.0     15.340650
# 9.0     15.895474
# 10.0    20.197148
# 11.0    16.170638
# 12.0    15.887671
# 13.0    16.583536
# 14.0    16.773669
# 15.0    16.165037
# 16.0    17.665606
# 17.0    15.694469
# 18.0    19.310397
# 19.0    17.177343
# 20.0    16.473447
# 21.0    22.902379
# Name: order_number, dtype: float64

# %%
#performing multiple aggregations 

print('The mean, min, and max of order_number grouped by the department_id:')
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
# The mean, min, and max of order_number grouped by the department_id:
#               order_number
#                       mean min max
# department_id
# 1.0              15.457838   1  99
# 2.0              17.277920   1  99
# 3.0              17.170395   1  99
# 4.0              17.811403   1  99
# 5.0              15.215751   1  99
# 6.0              16.439806   1  99
# 7.0              17.225802   1  99
# 8.0              15.340650   1  99
# 9.0              15.895474   1  99
# 10.0             20.197148   1  99
# 11.0             16.170638   1  99
# 12.0             15.887671   1  99
# 13.0             16.583536   1  99
# 14.0             16.773669   1  99
# 15.0             16.165037   1  99
# 16.0             17.665606   1  99
# 17.0             15.694469   1  99
# 18.0             19.310397   1  99
# 19.0             17.177343   1  99
# 20.0             16.473447   1  99
# 21.0             22.902379   1  99

# %% [markdown]
# # 2. Aggregating Data with Transform

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#function to display all rows
pd.options.display.max_rows = None

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
# 50   2550362        1            10                   4                  8
# 51   2550362        1            10                   4                  8
# 52   2550362        1            10                   4                  8
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
# 62   2168274        2             1                   2                 11
# 63   2168274        2             1                   2                 11
# 64   2168274        2             1                   2                 11
# 65   2168274        2             1                   2                 11
# 66   2168274        2             1                   2                 11
# 67   2168274        2             1                   2                 11
# 68   2168274        2             1                   2                 11
# 69   2168274        2             1                   2                 11
# 70   2168274        2             1                   2                 11
# 71   2168274        2             1                   2                 11
# 72   1501582        2             2                   5                 10
# 73   1501582        2             2                   5                 10
# 74   1501582        2             2                   5                 10
# 75   1501582        2             2                   5                 10
# 76   1501582        2             2                   5                 10
# 77   1501582        2             2                   5                 10
# 78   1901567        2             3                   1                 10
# 79   1901567        2             3                   1                 10
# 80   1901567        2             3                   1                 10
# 81   1901567        2             3                   1                 10
# 82   1901567        2             3                   1                 10
# 83    738281        2             4                   2                 10
# 84    738281        2             4                   2                 10
# 85    738281        2             4                   2                 10
# 86    738281        2             4                   2                 10
# 87    738281        2             4                   2                 10
# 88    738281        2             4                   2                 10
# 89    738281        2             4                   2                 10
# 90    738281        2             4                   2                 10
# 91    738281        2             4                   2                 10
# 92    738281        2             4                   2                 10
# 93    738281        2             4                   2                 10
# 94    738281        2             4                   2                 10
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
# 25                    28.0       10326                  5          0   both
# 26                    28.0       17122                  6          0   both
# 27                    28.0      -23749                  7          0   both
# 28                    28.0       13176                  8          1   both
# 29                    19.0         196                  1          1   both
# 30                    19.0       12427                  2          1   both
# 31                    19.0       10258                  3          1   both
# 32                    19.0       25133                  4          1   both
# 33                    20.0         196                  1          1   both
# 34                    20.0       10258                  2          1   both
# 35                    20.0       12427                  3          1   both
# 36                    20.0       25133                  4          1   both
# 37                    20.0       13032                  5          1   both
# 38                    14.0       12427                  1          1   both
# 39                    14.0         196                  2          1   both
# 40                    14.0       10258                  3          1   both
# 41                    14.0       25133                  4          1   both
# 42                    14.0      -19387                  5          0   both
# 43                    14.0      -16301                  6          0   both
# 44                     0.0      -16301                  1          1   both
# 45                     0.0      -19387                  2          1   both
# 46                     0.0       25133                  3          1   both
# 47                     0.0         196                  4          1   both
# 48                     0.0       10258                  5          1   both
# 49                     0.0       12427                  6          1   both
# 50                    30.0         196                  1          1   both
# 51                    30.0      -19387                  2          1   both
# 52                    30.0      -25879                  3          0   both
# 53                    30.0      -26608                  4          0   both
# 54                    30.0       25133                  5          1   both
# 55                    30.0       10258                  6          1   both
# 56                    30.0      -29585                  7          0   both
# 57                    30.0       13032                  8          1   both
# 58                    30.0       12427                  9          1   both
# 59                     NaN      -32744                  1          0   both
# 60                     NaN      -17770                  2          0   both
# 61                     NaN       20574                  3          0   both
# 62                     NaN       12000                  4          0   both
# 63                     NaN      -17426                  5          0   both
# 64                     NaN       22474                  6          0   both
# 65                     NaN       16589                  7          0   both
# 66                     NaN      -29619                  8          0   both
# 67                     NaN       27344                  9          0   both
# 68                     NaN       30489                 10          0   both
# 69                     NaN       27966                 11          0   both
# 70                     NaN       13176                 12          0   both
# 71                     NaN      -20470                 13          0   both
# 72                    10.0       16797                  1          0   both
# 73                    10.0      -18010                  2          0   both
# 74                    10.0        8479                  3          0   both
# 75                    10.0      -17770                  4          1   both
# 76                    10.0       19051                  5          0   both
# 77                    10.0        8138                  6          0   both
# 78                     3.0      -17770                  1          1   both
# 79                     3.0      -32744                  2          1   both
# 80                     3.0       20574                  3          1   both
# 81                     3.0        7781                  4          0   both
# 82                     3.0       28874                  5          0   both
# 83                     8.0      -16085                  1          0   both
# 84                     8.0      -32744                  2          1   both
# 85                     8.0       32139                  3          0   both
# 86                     8.0      -30848                  4          0   both
# 87                     8.0      -28801                  5          0   both
# 88                     8.0      -27890                  6          0   both
# 89                     8.0       22829                  7          0   both
# 90                     8.0       24852                  8          0   both
# 91                     8.0      -18327                  9          0   both
# 92                     8.0      -32260                 10          0   both
# 93                     8.0      -19923                 11          0   both
# 94                     8.0        9681                 12          0   both
# 95                     8.0       21150                 13          0   both
# 96                     8.0      -18392                  1          0   both
# 97                     8.0        5322                  2          0   both
# 98                     8.0       17224                  3          0   both
# 99                     8.0      -26880                  4          0   both
#
#                                          product_name  aisle_id  \
# 0                                                Soda      77.0
# 1             Organic Unsweetened Vanilla Almond Milk      91.0
# 2                                 Original Beef Jerky      23.0
# 3                          Aged White Cheddar Popcorn      23.0
# 4                    XL Pick-A-Size Paper Towel Rolls      54.0
# 5                                                Soda      77.0
# 6                                          Pistachios     117.0
# 7                                 Original Beef Jerky      23.0
# 8                              Bag of Organic Bananas      24.0
# 9                          Aged White Cheddar Popcorn      23.0
# 10                              Cinnamon Toast Crunch     121.0
# 11                                               Soda      77.0
# 12                                Original Beef Jerky      23.0
# 13                                         Pistachios     117.0
# 14                              Organic String Cheese      21.0
# 15                               Creamy Almond Butter      88.0
# 16                                               Soda      77.0
# 17                                Original Beef Jerky      23.0
# 18                                         Pistachios     117.0
# 19                              Organic String Cheese      21.0
# 20                   XL Pick-A-Size Paper Towel Rolls      54.0
# 21                                               Soda      77.0
# 22                                Original Beef Jerky      23.0
# 23                                         Pistachios     117.0
# 24                              Organic String Cheese      21.0
# 25                                Organic Fuji Apples      24.0
# 26                                  Honeycrisp Apples      24.0
# 27                                     Bartlett Pears      24.0
# 28                             Bag of Organic Bananas      24.0
# 29                                               Soda      77.0
# 30                                Original Beef Jerky      23.0
# 31                                         Pistachios     117.0
# 32                              Organic String Cheese      21.0
# 33                                               Soda      77.0
# 34                                         Pistachios     117.0
# 35                                Original Beef Jerky      23.0
# 36                              Organic String Cheese      21.0
# 37                              Cinnamon Toast Crunch     121.0
# 38                                Original Beef Jerky      23.0
# 39                                               Soda      77.0
# 40                                         Pistachios     117.0
# 41                              Organic String Cheese      21.0
# 42                                  Zero Calorie Cola      77.0
# 43                                Organic Half & Half      53.0
# 44                                Organic Half & Half      53.0
# 45                                  Zero Calorie Cola      77.0
# 46                              Organic String Cheese      21.0
# 47                                               Soda      77.0
# 48                                         Pistachios     117.0
# 49                                Original Beef Jerky      23.0
# 50                                               Soda      77.0
# 51                                  Zero Calorie Cola      77.0
# 52                             Milk Chocolate Almonds      45.0
# 53                           0% Greek Strained Yogurt     120.0
# 54                              Organic String Cheese      21.0
# 55                                         Pistachios     117.0
# 56                    Organic Unsweetened Almond Milk      91.0
# 57                              Cinnamon Toast Crunch     121.0
# 58                                Original Beef Jerky      23.0
# 59                     Chipotle Beef & Pork Realstick      23.0
# 60                                    Organic Avocado      24.0
# 61                                     Roasted Turkey      96.0
# 62           Baked Organic Sea Salt Crunchy Pea Snack      72.0
# 63            Thin Stackers Brown Rice Lightly Salted      78.0
# 64                     Cheddar Bunnies Snack Crackers      78.0
# 65                                     Plantain Chips     107.0
# 66                   Organic Just Concord Grape Juice      98.0
# 67                               Uncured Genoa Salami      96.0
# 68                                    Original Hummus      67.0
# 69                                Organic Raspberries     123.0
# 70                             Bag of Organic Bananas      24.0
# 71                                   Honeycrisp Apple      24.0
# 72                                       Strawberries      24.0
# 73                                    Goat Cheese Log      21.0
# 74              Original Black Box Tablewater Cracker      78.0
# 75                                    Organic Avocado      24.0
# 76               Pita Chips, Simply Naked, Party Size     107.0
# 77                                 Traditional Hummus      67.0
# 78                                    Organic Avocado      24.0
# 79                     Chipotle Beef & Pork Realstick      23.0
# 80                                     Roasted Turkey      96.0
# 81  Organic Sticks Low Moisture Part Skim Mozzarel...      21.0
# 82                                 Carrot Ginger Soup       1.0
# 83                              Artichoke Spinach Dip      67.0
# 84                     Chipotle Beef & Pork Realstick      23.0
# 85                            Hommus Classic Original      67.0
# 86  Good Belly Probiotics Juice Drink Blueberry Ac...      31.0
# 87              Organic Roasted Sliced Chicken Breast      96.0
# 88                                Organic Gala Apples      24.0
# 89          Multigrain Flax Seeded Flatbread Crackers      78.0
# 90                                             Banana      24.0
# 91                               Organic Hass Avocado      24.0
# 92                              Kalamata Olive Spread      67.0
# 93                                           Pad Thai      38.0
# 94  Chicken Tikka Masala with Cumin Infused Basmat...      38.0
# 95                            Fire Grilled Steak Bowl      38.0
# 96     Unsweetened Original Almond Breeze Almond Milk      91.0
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...       3.0
# 98                   Oats & Honey Gluten Free Granola       3.0
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...       3.0
#
#     department_id  prices    price_range_loc    busiest_days  \
# 0             7.0     9.0  Mid-range product  Regularly busy
# 1            16.0    12.5  Mid-range product  Regularly busy
# 2            19.0     4.4  Low-range product  Regularly busy
# 3            19.0     4.7  Low-range product  Regularly busy
# 4            17.0     1.0  Low-range product  Regularly busy
# 5             7.0     9.0  Mid-range product    Slowest days
# 6            19.0     3.0  Low-range product    Slowest days
# 7            19.0     4.4  Low-range product    Slowest days
# 8             4.0    10.3  Mid-range product    Slowest days
# 9            19.0     4.7  Low-range product    Slowest days
# 10           14.0     4.0  Low-range product    Slowest days
# 11            7.0     9.0  Mid-range product    Slowest days
# 12           19.0     4.4  Low-range product    Slowest days
# 13           19.0     3.0  Low-range product    Slowest days
# 14           16.0     8.6  Mid-range product    Slowest days
# 15           13.0     3.2  Low-range product    Slowest days
# 16            7.0     9.0  Mid-range product    Slowest days
# 17           19.0     4.4  Low-range product    Slowest days
# 18           19.0     3.0  Low-range product    Slowest days
# 19           16.0     8.6  Mid-range product    Slowest days
# 20           17.0     1.0  Low-range product    Slowest days
# 21            7.0     9.0  Mid-range product    Slowest days
# 22           19.0     4.4  Low-range product    Slowest days
# 23           19.0     3.0  Low-range product    Slowest days
# 24           16.0     8.6  Mid-range product    Slowest days
# 25            4.0     2.7  Low-range product    Slowest days
# 26            4.0    14.0  Mid-range product    Slowest days
# 27            4.0     5.0  Low-range product    Slowest days
# 28            4.0    10.3  Mid-range product    Slowest days
# 29            7.0     9.0  Mid-range product  Regularly busy
# 30           19.0     4.4  Low-range product  Regularly busy
# 31           19.0     3.0  Low-range product  Regularly busy
# 32           16.0     8.6  Mid-range product  Regularly busy
# 33            7.0     9.0  Mid-range product    Busiest days
# 34           19.0     3.0  Low-range product    Busiest days
# 35           19.0     4.4  Low-range product    Busiest days
# 36           16.0     8.6  Mid-range product    Busiest days
# 37           14.0     4.0  Low-range product    Busiest days
# 38           19.0     4.4  Low-range product    Busiest days
# 39            7.0     9.0  Mid-range product    Busiest days
# 40           19.0     3.0  Low-range product    Busiest days
# 41           16.0     8.6  Mid-range product    Busiest days
# 42            7.0    13.4  Mid-range product    Busiest days
# 43           16.0     1.8  Low-range product    Busiest days
# 44           16.0     1.8  Low-range product    Busiest days
# 45            7.0    13.4  Mid-range product    Busiest days
# 46           16.0     8.6  Mid-range product    Busiest days
# 47            7.0     9.0  Mid-range product    Busiest days
# 48           19.0     3.0  Low-range product    Busiest days
# 49           19.0     4.4  Low-range product    Busiest days
# 50            7.0     9.0  Mid-range product    Slowest days
# 51            7.0    13.4  Mid-range product    Slowest days
# 52           19.0     6.8  Mid-range product    Slowest days
# 53           16.0    12.6  Mid-range product    Slowest days
# 54           16.0     8.6  Mid-range product    Slowest days
# 55           19.0     3.0  Low-range product    Slowest days
# 56           16.0     1.3  Low-range product    Slowest days
# 57           14.0     4.0  Low-range product    Slowest days
# 58           19.0     4.4  Low-range product    Slowest days
# 59           19.0     5.2  Mid-range product  Regularly busy
# 60            4.0     6.3  Mid-range product  Regularly busy
# 61           20.0     2.3  Low-range product  Regularly busy
# 62           13.0    10.9  Mid-range product  Regularly busy
# 63           19.0     2.7  Low-range product  Regularly busy
# 64           19.0     4.1  Low-range product  Regularly busy
# 65           19.0     5.0  Low-range product  Regularly busy
# 66            7.0     9.4  Mid-range product  Regularly busy
# 67           20.0    14.8  Mid-range product  Regularly busy
# 68           20.0     7.5  Mid-range product  Regularly busy
# 69            4.0     4.4  Low-range product  Regularly busy
# 70            4.0    10.3  Mid-range product  Regularly busy
# 71            4.0     2.5  Low-range product  Regularly busy
# 72            4.0     1.3  Low-range product  Regularly busy
# 73           16.0     2.0  Low-range product  Regularly busy
# 74           19.0     3.5  Low-range product  Regularly busy
# 75            4.0     6.3  Mid-range product  Regularly busy
# 76           19.0     3.9  Low-range product  Regularly busy
# 77           20.0     2.0  Low-range product  Regularly busy
# 78            4.0     6.3  Mid-range product    Busiest days
# 79           19.0     5.2  Mid-range product    Busiest days
# 80           20.0     2.3  Low-range product    Busiest days
# 81           16.0     6.6  Mid-range product    Busiest days
# 82           20.0     6.2  Mid-range product    Busiest days
# 83           20.0     7.1  Mid-range product  Regularly busy
# 84           19.0     5.2  Mid-range product  Regularly busy
# 85           20.0     7.5  Mid-range product  Regularly busy
# 86            7.0     5.8  Mid-range product  Regularly busy
# 87           20.0     8.9  Mid-range product  Regularly busy
# 88            4.0     9.1  Mid-range product  Regularly busy
# 89           19.0     5.5  Mid-range product  Regularly busy
# 90            4.0    12.3  Mid-range product  Regularly busy
# 91            4.0     4.0  Low-range product  Regularly busy
# 92           20.0    10.8  Mid-range product  Regularly busy
# 93            1.0    12.6  Mid-range product  Regularly busy
# 94            1.0     2.0  Low-range product  Regularly busy
# 95            1.0     5.9  Mid-range product  Regularly busy
# 96           16.0    14.0  Mid-range product    Slowest days
# 97           19.0     2.9  Low-range product    Slowest days
# 98           19.0     1.6  Low-range product    Slowest days
# 99           19.0     3.4  Low-range product    Slowest days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# 5         Average orders         10
# 6         Average orders         10
# 7         Average orders         10
# 8         Average orders         10
# 9         Average orders         10
# 10        Average orders         10
# 11           Most orders         10
# 12           Most orders         10
# 13           Most orders         10
# 14           Most orders         10
# 15           Most orders         10
# 16        Average orders         10
# 17        Average orders         10
# 18        Average orders         10
# 19        Average orders         10
# 20        Average orders         10
# 21           Most orders         10
# 22           Most orders         10
# 23           Most orders         10
# 24           Most orders         10
# 25           Most orders         10
# 26           Most orders         10
# 27           Most orders         10
# 28           Most orders         10
# 29        Average orders         10
# 30        Average orders         10
# 31        Average orders         10
# 32        Average orders         10
# 33           Most orders         10
# 34           Most orders         10
# 35           Most orders         10
# 36           Most orders         10
# 37           Most orders         10
# 38           Most orders         10
# 39           Most orders         10
# 40           Most orders         10
# 41           Most orders         10
# 42           Most orders         10
# 43           Most orders         10
# 44           Most orders         10
# 45           Most orders         10
# 46           Most orders         10
# 47           Most orders         10
# 48           Most orders         10
# 49           Most orders         10
# 50        Average orders         10
# 51        Average orders         10
# 52        Average orders         10
# 53        Average orders         10
# 54        Average orders         10
# 55        Average orders         10
# 56        Average orders         10
# 57        Average orders         10
# 58        Average orders         10
# 59           Most orders         14
# 60           Most orders         14
# 61           Most orders         14
# 62           Most orders         14
# 63           Most orders         14
# 64           Most orders         14
# 65           Most orders         14
# 66           Most orders         14
# 67           Most orders         14
# 68           Most orders         14
# 69           Most orders         14
# 70           Most orders         14
# 71           Most orders         14
# 72           Most orders         14
# 73           Most orders         14
# 74           Most orders         14
# 75           Most orders         14
# 76           Most orders         14
# 77           Most orders         14
# 78           Most orders         14
# 79           Most orders         14
# 80           Most orders         14
# 81           Most orders         14
# 82           Most orders         14
# 83           Most orders         14
# 84           Most orders         14
# 85           Most orders         14
# 86           Most orders         14
# 87           Most orders         14
# 88           Most orders         14
# 89           Most orders         14
# 90           Most orders         14
# 91           Most orders         14
# 92           Most orders         14
# 93           Most orders         14
# 94           Most orders         14
# 95           Most orders         14
# 96           Most orders         14
# 97           Most orders         14
# 98           Most orders         14
# 99           Most orders         14

# %% [markdown]
# # Deriving Columns with loc()

# %%
#creating my flag based on values using loc()

# %%
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[df['max_order'] <= 40, 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
#checking output of certain columns
df[['user_id', 'loyalty_flag', 'max_order']].sample(60)
# Out:
#           user_id      loyalty_flag  max_order
# 11885032    75249  Regular customer         11
# 11104556    70344      New customer          7
# 27881156   177171  Regular customer         23
# 13382167    84652    Loyal customer         85
# 14095958    89247  Regular customer         12
# 16390029   103672  Regular customer         32
# 20273069   128648      New customer          9
# 31982890   203256    Loyal customer         99
# 16923324   107124  Regular customer         38
# 26472203   168292      New customer          4
# 17647093   111593  Regular customer         30
# 30103164   191261  Regular customer         24
# 22943851   145695    Loyal customer         57
# 4613972     29411    Loyal customer         45
# 18660734   118109      New customer          5
# 23237551   147534    Loyal customer         69
# 2861092     18276  Regular customer         35
# 13153931    83276      New customer          4
# 6930895     43989    Loyal customer         86
# 22198539   141003  Regular customer         24
# 31673427   201283    Loyal customer         64
# 13708993    86773    Loyal customer         68
# 26220676   166648      New customer          9
# 11878469    75192  Regular customer         19
# 29935707   190207  Regular customer         30
# 27501345   174814      New customer          3
# 4898383     31182    Loyal customer         68
# 31724108   201623    Loyal customer         99
# 27873224   177124      New customer          7
# 7589883     48148    Loyal customer         44
# 13547348    85731    Loyal customer         74
# 19362896   122692      New customer          6
# 3771533     23956      New customer          8
# 14100993    89272  Regular customer         21
# 18731205   118562  Regular customer         17
# 32374178   205802  Regular customer         28
# 22338009   141878    Loyal customer         47
# 11026392    69858      New customer          9
# 950820       6147      New customer          9
# 28959149   183981    Loyal customer         99
# 17588148   111207  Regular customer         11
# 25360178   160989      New customer          8
# 11031671    69880  Regular customer         40
# 4927343     31379  Regular customer         32
# 543024       3616      New customer          6
# 9112261     57785  Regular customer         11
# 5324322     33831    Loyal customer         59
# 25288917   160550    Loyal customer         42
# 333536       2245    Loyal customer         41
# 3217249     20670  Regular customer         17
# 15833764   100175  Regular customer         30
# 7876858     49969      New customer         10
# 26794615   170365  Regular customer         36
# 9081166     57548  Regular customer         16
# 4967127     31632    Loyal customer         45
# 4289886     27262  Regular customer         34
# 12974529    82079  Regular customer         22
# 26569986   168947      New customer          8
# 3806602     24158  Regular customer         33
# 10823469    68589  Regular customer         14

# %%
#export dataframe 
df.to_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'full_merged4.pkl'))
