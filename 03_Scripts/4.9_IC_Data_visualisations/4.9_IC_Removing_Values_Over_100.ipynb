# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create usable path 
path = r'C:\Users\rutha\CareerFoundry\01-23_Instacart_Basket_Analysis'

# %%
#import data set
df = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'orders_products_all.pkl'))

# %%
#check output 
print('Sample of most recent data set')
df.sample(5)
# Out:
# Sample of most recent data set
#           order_id  user_id  order_number  orders_day_of_week  \
# 27314855   1749182   173604            36                   5
# 9259078    1150717    58802            17                   2
# 31736655   3384255   201701             3                   6
# 6552553    3015594    41700            16                   3
# 21309387   3260765   135367            47                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 27314855                 10                    15.0       27104
# 9259078                   9                    27.0      -19014
# 31736655                 10                     9.0       26689
# 6552553                  11                     9.0       19468
# 21309387                 18                     5.0       19019
#
#           add_to_cart_order  reordered _merge  ... order_freq  \
# 27314855                 10          1   both  ...        9.0
# 9259078                  16          1   both  ...        9.0
# 31736655                  4          1   both  ...       10.0
# 6552553                   3          0   both  ...       18.0
# 21309387                  8          0   both  ...        7.0
#
#             order_freq_flag  gender  state age date_joined n_dependants  \
# 27314855  Frequent customer  Female     WY  77  2017-01-06            2
# 9259078   Frequent customer  Female     WI  18  2018-04-30            0
# 31736655  Frequent customer    Male     VA  54  2019-12-07            1
# 6552553    Regular customer  Female     MD  24  2020-01-21            3
# 21309387  Frequent customer  Female     ID  57  2020-02-29            0
#
#           dependants_loc fam_status  income
# 27314855  Has dependants    married  147134
# 9259078    No dependants     single   38421
# 31736655  Has dependants    married  154615
# 6552553   Has dependants    married   34437
# 21309387   No dependants     single  139089
#
# [5 rows x 31 columns]

# %%
#locating all products with a value of 100 or more
df.loc[df['prices'] > 100]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16534      3264360      135             2                   2
# 16540       892534      135             3                   0
# 53712       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32350634   3172853   205650            18                   1
# 32377867   2504315   205818             3                   5
# 32377877   1108388   205818             5                   4
# 32410707   1916142   206049             1                   2
# 32410731    379732   206049             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 1576                     14                     5.0       21553
# 1638                     16                     4.0       21553
# 16534                    21                    13.0       21553
# 16540                     8                    12.0       21553
# 53712                    19                    30.0       21553
# ...                     ...                     ...         ...
# 32350634                  9                     7.0       21553
# 32377867                 15                     3.0       21553
# 32377877                  5                     1.0       21553
# 32410707                 17                     NaN       21553
# 32410731                 14                     5.0       21553
#
#           add_to_cart_order  reordered _merge  ... order_freq  \
# 1576                      5          0   both  ...        5.0
# 1638                      3          1   both  ...        5.0
# 16534                     6          0   both  ...       12.0
# 16540                     3          1   both  ...       12.0
# 53712                     9          0   both  ...       23.0
# ...                     ...        ...    ...  ...        ...
# 32350634                 17          1   both  ...        6.0
# 32377867                 13          0   both  ...       12.5
# 32377877                  5          1   both  ...       12.5
# 32410707                  2          0   both  ...        7.0
# 32410731                  4          1   both  ...        7.0
#
#                 order_freq_flag  gender  state age date_joined n_dependants  \
# 1576          Frequent customer  Female     KS  39  2018-09-16            3
# 1638          Frequent customer  Female     KS  39  2018-09-16            3
# 16534          Regular customer  Female     MD  30  2017-03-19            3
# 16540          Regular customer  Female     MD  30  2017-03-19            3
# 53712     Non-frequent customer  Female     MN  56  2018-08-23            2
# ...                         ...     ...    ...  ..         ...          ...
# 32350634      Frequent customer    Male     KY  62  2017-10-02            0
# 32377867       Regular customer    Male     MD  60  2019-07-12            1
# 32377877       Regular customer    Male     MD  60  2019-07-12            1
# 32410707      Frequent customer  Female     DC  23  2019-04-26            1
# 32410731      Frequent customer  Female     DC  23  2019-04-26            1
#
#           dependants_loc        fam_status  income
# 1576      Has dependants           married  150659
# 1638      Has dependants           married  150659
# 16534     Has dependants           married  120635
# 16540     Has dependants           married  120635
# 53712     Has dependants           married  187328
# ...                  ...               ...     ...
# 32350634   No dependants  divorced/widowed  302526
# 32377867  Has dependants           married  172539
# 32377877  Has dependants           married  172539
# 32410707  Has dependants           married  169022
# 32410731  Has dependants           married  169022
#
# [5127 rows x 31 columns]

# %%
#turning all values over 100 into NaN
df.loc[df['prices'] > 100, 'prices'] = np.nan

# %%
#checking output
df['prices'].max()
# Out:
# 25.0

# %%
#export data
