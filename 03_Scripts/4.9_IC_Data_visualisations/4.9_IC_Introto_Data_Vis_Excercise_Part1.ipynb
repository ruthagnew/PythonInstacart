# %% [markdown]
# # Creating charts and visualisations in Python
#
# 1. Addressing our new data set
#     1. Wrangling
#     2. Cleaning
#     3. Merging with existing dataset
# 2. Creating visualisations (included in Part2 notebook)

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\rutha\CareerFoundry\01-23_Instacart_Basket_Analysis'

# %%
#import customers data set
df = pd.read_csv(os.path.join(path, '02_Data', 'Original_data', 'customers.csv'), index_col=False)

# %%
#checking output
print('Sample of new customers data set')
df.head(10)
# Out:
# Sample of new customers data set
#    user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374
# 5             2    married   49643
# 6             0     single   61746
# 7             0     single   63712
# 8             1    married  162432
# 9             2    married   32072

# %%
print('Number of rows and columns in customers data set')
df.shape
# Out:
# Number of rows and columns in customers data set
# (206209, 10)

# %% [markdown]
# ##### Initial observations:

# %% [markdown]
# Our new customers data set provides personal information about Instacart's customer base including first name, surname, gender, state location, age, when they joined Instacart, the number of dependents they have, their family status, and finally their income. Already there are some spelling and syntactical errors in the column names which we will be able to fix to make the data set easier to understand.
#
# There are 206,209 rows, so lot's of customers!

# %% [markdown]
# ### A. Data Wrangling

# %% [markdown]
# #### Approach
#
# 1. Some simple exploratory analysis to understand a couple of the columns.
# 2. Removal of the first_name, and surname columns. User_id is a more useful customer identifier than first or surname.
# 3. Amend any spelling and syntactical errors in the column titles. This will include use of capital and lowercase letters, and use of underscores and spaces.
# 4. Check data types of columns to ensure they are correct and appropriate for the type of data collected
# 5. Use a data dictionary to change the data within the STATE column to two-letter codes. Although not specifically needed, reducing the data to two-letters is cleaner, and would make it easier to, for example, search for specific states using the isin fucntion.
# 6. Create a new column with flag related to whether or not the customer has dependents. Instacart could provide targeted advertising to individuals based on whether they have dependents on not.

# %% [markdown]
# ##### 1. Initial exploratory analysis to understand some of the columns

# %%
#checking gender column
df['Gender'].value_counts()
# Out:
# Male      104067
# Female    102142
# Name: Gender, dtype: int64

# %%
#checking age column
df['Age'].value_counts()
# Out:
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: Age, Length: 64, dtype: int64

# %%
df['Age'].describe()
# Out:
# count    206209.000000
# mean         49.501646
# std          18.480962
# min          18.000000
# 25%          33.000000
# 50%          49.000000
# 75%          66.000000
# max          81.000000
# Name: Age, dtype: float64

# %%
#checking fam_status column
df['fam_status'].value_counts()
# Out:
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: fam_status, dtype: int64

# %%
#checking income column
df['income'].describe()
# Out:
# count    206209.000000
# mean      94632.852548
# std       42473.786988
# min       25903.000000
# 25%       59874.000000
# 50%       93547.000000
# 75%      124244.000000
# max      593901.000000
# Name: income, dtype: float64

# %%
#checking n_dependants
df['n_dependants'].describe()
# Out:
# count    206209.000000
# mean          1.499823
# std           1.118433
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max           3.000000
# Name: n_dependants, dtype: float64

# %% [markdown]
# ##### Observations:

# %% [markdown]
# I wanted to understand more about the types of values contained within these columns before I started amending anything. Everything so far seems reasonable.

# %% [markdown]
# ##### 2. Removal of first name and surname columns

# %%
#remove date_joined column using drop function
df.drop(columns = ['First Name', 'Surnam'])
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# 3          single   42049
# 4         married   40374
# ...           ...     ...
# 206204    married  148828
# 206205    married  168639
# 206206    married   53374
# 206207    married   99799
# 206208    married   57095
#
# [206209 rows x 8 columns]

# %%
#define dateframe minus date_joined column
df = df.drop(columns = ['First Name', 'Surnam'])

# %%
#check output
df.head()
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    33890  Female  New Mexico   36    1/1/2017             0     single
# 2    65803    Male       Idaho   35    1/1/2017             2    married
# 3   125935  Female        Iowa   40    1/1/2017             0     single
# 4   130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
#checking shape
df.shape
# Out:
# (206209, 8)

# %% [markdown]
# ##### 3. Amending spelling and syntax errors in columns names

# %%
#amending First Name, Surnam, Gender, STATE, and Age columns
df.rename(columns = {'Gender':'gender', 'STATE':'state', 'Age':'age'}, inplace = True)

# %%
df.head()
# Out:
#    user_id  gender       state  age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    33890  Female  New Mexico   36    1/1/2017             0     single
# 2    65803    Male       Idaho   35    1/1/2017             2    married
# 3   125935  Female        Iowa   40    1/1/2017             0     single
# 4   130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %% [markdown]
# ##### 4. Checking datatypes

# %%
#returning the datatypes for all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   gender        206209 non-null  object
#  2   state         206209 non-null  object
#  3   age           206209 non-null  int64
#  4   date_joined   206209 non-null  object
#  5   n_dependants  206209 non-null  int64
#  6   fam_status    206209 non-null  object
#  7   income        206209 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.6+ MB

# %% [markdown]
# ###### Observations:

# %% [markdown]
# Whilst the majority of the datatypes themselves are all correct, we should reduce the size of some of them to save on space. The date_joined column should be changed to datetime.

# %%
#amending datatype for user_id, age, n_dependents, and income
df['user_id']=df['user_id'].astype('int32')
df['age'] =df['age'].astype('int8')
df['date_joined'] = df['date_joined'].apply(pd.to_datetime)
df['n_dependants']=df['n_dependants'].astype('int16')
df['income']=df['income'].astype('int32')

# %%
#checking output
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int32
#  1   gender        206209 non-null  object
#  2   state         206209 non-null  object
#  3   age           206209 non-null  int8
#  4   date_joined   206209 non-null  datetime64[ns]
#  5   n_dependants  206209 non-null  int16
#  6   fam_status    206209 non-null  object
#  7   income        206209 non-null  int32
# dtypes: datetime64[ns](1), int16(1), int32(2), int8(1), object(3)
# memory usage: 8.5+ MB

# %%
df.head()
# Out:
#    user_id  gender       state  age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48  2017-01-01             3    married
# 1    33890  Female  New Mexico   36  2017-01-01             0     single
# 2    65803    Male       Idaho   35  2017-01-01             2    married
# 3   125935  Female        Iowa   40  2017-01-01             0     single
# 4   130797  Female    Maryland   26  2017-01-01             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %% [markdown]
# ##### 5. Using a data dictionary to change state names to two-letter abbreviations

# %%
#creating list of all state names
states_listed = df['state'].unique()

# %%
#checking output
print(sorted(states_listed))
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
#number of each state
df['state'].value_counts().sort_index()
# Out:
# Alabama                 4044
# Alaska                  4044
# Arizona                 4044
# Arkansas                4044
# California              4044
# Colorado                4044
# Connecticut             4044
# Delaware                4044
# District of Columbia    4044
# Florida                 4044
# Georgia                 4044
# Hawaii                  4044
# Idaho                   4044
# Illinois                4044
# Indiana                 4044
# Iowa                    4044
# Kansas                  4043
# Kentucky                4043
# Louisiana               4043
# Maine                   4043
# Maryland                4043
# Massachusetts           4043
# Michigan                4043
# Minnesota               4043
# Mississippi             4043
# Missouri                4043
# Montana                 4043
# Nebraska                4043
# Nevada                  4043
# New Hampshire           4043
# New Jersey              4043
# New Mexico              4043
# New York                4043
# North Carolina          4043
# North Dakota            4043
# Ohio                    4043
# Oklahoma                4043
# Oregon                  4043
# Pennsylvania            4043
# Rhode Island            4043
# South Carolina          4043
# South Dakota            4043
# Tennessee               4043
# Texas                   4043
# Utah                    4043
# Vermont                 4043
# Virginia                4043
# Washington              4043
# West Virginia           4043
# Wisconsin               4043
# Wyoming                 4043
# Name: state, dtype: int64

# %%
#counting number of states
state_count = df['state'].nunique()
print(state_count)
# Out:
# 51

# %%
#creating data dictionary, abbreviations were retrieved from US government website
state_dict = {'Alabama': 'AL',
              'Alaska': 'AK', 
              'Arizona': 'AZ',
              'Arkansas': 'AR',
              'California': 'CA',
              'Colorado': 'CO',
              'Connecticut': 'CT',
              'Delaware': 'DE',
              'District of Columbia': 'DC',
              'Florida': 'FL',
              'Georgia': 'GA',
              'Hawaii': 'HI',
              'Idaho': 'ID',
              'Illinois': 'IL',
              'Indiana': 'IN',
              'Iowa': 'IA',
              'Kansas': 'KS',
              'Kentucky': 'KY',
              'Louisiana': 'LA',
              'Maine': 'ME',
              'Maryland': 'MD',
              'Massachusetts': 'MA',
              'Michigan': 'MI',
              'Minnesota': 'MN',
              'Mississippi': 'MS',
              'Missouri': 'MO',
              'Montana': 'MT',
              'Nebraska': 'NE',
              'Nevada': 'NV',
              'New Hampshire': 'NH',
              'New Jersey': 'NJ',
              'New Mexico': 'NM',
              'New York': 'NY',
              'North Carolina': 'NC',
              'North Dakota': 'ND',
              'Ohio': 'OH',
              'Oklahoma': 'OK',
              'Oregon': 'OR',
              'Pennsylvania': 'PA',
              'Rhode Island': 'RI',
              'South Carolina': 'SC',
              'South Dakota': 'SD',
              'Tennessee': 'TN',
              'Texas': 'TX',
              'Utah': 'UT',
              'Vermont': 'VT',
              'Virginia': 'VA',
              'Washington': 'WA',
              'West Virginia': 'WV',
              'Wisconsin': 'WI',
              'Wyoming': 'WY'}

# %%
#replace values in state column with state dictionary 
df2 = df.replace({'state': state_dict})

# %%
df2.sample(10)
# Out:
#         user_id  gender state  age date_joined  n_dependants  \
# 128426    26550  Female    OH   72  2019-01-10             0
# 142541    93639  Female    AZ   34  2019-04-02             0
# 68676    178491    Male    SD   74  2018-01-31             2
# 128647    90007    Male    TN   27  2019-01-12             2
# 56031     63847    Male    VT   50  2017-11-19             2
# 126204    45355  Female    IA   72  2018-12-28             2
# 72208     89708    Male    WI   51  2018-02-20             3
# 156807    59609    Male    SC   51  2019-06-23             0
# 199790   107413    Male    CT   43  2020-02-25             0
# 142396    85738    Male    CT   43  2019-04-01             0
#
#               fam_status  income
# 128426  divorced/widowed  120650
# 142541            single  100379
# 68676            married  120201
# 128647           married   28281
# 56031            married  128293
# 126204           married   35600
# 72208            married  147863
# 156807            single  158852
# 199790            single  136330
# 142396            single  108260

# %%
df2['state'].value_counts().sort_index()
# Out:
# AK    4044
# AL    4044
# AR    4044
# AZ    4044
# CA    4044
# CO    4044
# CT    4044
# DC    4044
# DE    4044
# FL    4044
# GA    4044
# HI    4044
# IA    4044
# ID    4044
# IL    4044
# IN    4044
# KS    4043
# KY    4043
# LA    4043
# MA    4043
# MD    4043
# ME    4043
# MI    4043
# MN    4043
# MO    4043
# MS    4043
# MT    4043
# NC    4043
# ND    4043
# NE    4043
# NH    4043
# NJ    4043
# NM    4043
# NV    4043
# NY    4043
# OH    4043
# OK    4043
# OR    4043
# PA    4043
# RI    4043
# SC    4043
# SD    4043
# TN    4043
# TX    4043
# UT    4043
# VA    4043
# VT    4043
# WA    4043
# WI    4043
# WV    4043
# WY    4043
# Name: state, dtype: int64

# %% [markdown]
# The value counts for the new column matches those for the state column in the original dataframe

# %% [markdown]
# ##### 6. Create a new flag column on whether the customer has dependants

# %%
df2.loc[df2['n_dependants'] >= 1, 'dependants_loc'] = 'Has dependants'

# %%
df2.loc[df2['n_dependants'] < 1, 'dependants_loc'] = 'No dependants'

# %%
df2['dependants_loc'].value_counts(dropna = False)
# Out:
# Has dependants    154607
# No dependants      51602
# Name: dependants_loc, dtype: int64

# %%
df2.head()
# Out:
#    user_id  gender state  age date_joined  n_dependants fam_status  income  \
# 0    26711  Female    MO   48  2017-01-01             3    married  165665
# 1    33890  Female    NM   36  2017-01-01             0     single   59285
# 2    65803    Male    ID   35  2017-01-01             2    married   99568
# 3   125935  Female    IA   40  2017-01-01             0     single   42049
# 4   130797  Female    MD   26  2017-01-01             1    married   40374
#
#    dependants_loc
# 0  Has dependants
# 1   No dependants
# 2  Has dependants
# 3   No dependants
# 4  Has dependants

# %% [markdown]
# Although the code has worked, I would prefer for my two columns related to dependents to be situated next to one another.

# %%
#creating a list of my column titles
titles = list(df2.columns)
titles
# Out:
# ['user_id',
#  'gender',
#  'state',
#  'age',
#  'date_joined',
#  'n_dependants',
#  'fam_status',
#  'income',
#  'dependants_loc']

# %%
#creating a new list, with the new changed order of columns
new_titles = ['user_id',
 'gender',
 'state',
 'age',
 'date_joined',
 'n_dependants',
 'dependants_loc',
 'fam_status',
 'income']

# %%
#assigning my new column title order to my dataframe
df3 = df2[new_titles]

# %%
#checking my output
df3.sample(5)
# Out:
#         user_id  gender state  age date_joined  n_dependants  dependants_loc  \
# 104393    32297  Female    IL   21  2018-08-24             2  Has dependants
# 73238    118266    Male    WA   59  2018-02-26             2  Has dependants
# 21300    132714  Female    HI   72  2017-05-03             3  Has dependants
# 103021   124206  Female    MT   79  2018-08-16             3  Has dependants
# 185152   152139  Female    CO   76  2019-12-03             2  Has dependants
#
#                               fam_status  income
# 104393  living with parents and siblings   85094
# 73238                            married  101290
# 21300                            married  169298
# 103021                           married  100690
# 185152                           married  120733

# %% [markdown]
# #### Final check of shape and size of dataframe

# %%
df3.sample(10)
# Out:
#         user_id  gender state  age date_joined  n_dependants  dependants_loc  \
# 199038     5739  Female    NY   73  2020-02-21             1  Has dependants
# 44953     26230  Female    IA   18  2017-09-16             2  Has dependants
# 197290    86976  Female    MT   58  2020-02-11             3  Has dependants
# 161644   167259    Male    OH   61  2019-07-21             0   No dependants
# 32858      6628    Male    WV   71  2017-07-10             3  Has dependants
# 522      115909  Female    MS   43  2017-01-04             0   No dependants
# 114710   165982    Male    NC   26  2018-10-23             2  Has dependants
# 36598     81290  Female    VA   40  2017-07-31             1  Has dependants
# 129362   132154    Male    ID   63  2019-01-16             0   No dependants
# 74124    200781  Female    UT   46  2018-03-03             1  Has dependants
#
#                               fam_status  income
# 199038                           married  154533
# 44953   living with parents and siblings   86399
# 197290                           married  169883
# 161644                  divorced/widowed   65500
# 32858                            married   34593
# 522                               single  162037
# 114710                           married   68901
# 36598                            married  100956
# 129362                  divorced/widowed   94481
# 74124                            married   47856

# %%
df3.shape
# Out:
# (206209, 9)

# %% [markdown]
# ##### Final Observations

# %% [markdown]
# In terms of the shape of our dataframe, we have the same number of rows as before. We have dropped three columns, first name, surname, and date_joined, and created another, dependants_loc.
#
# We have also ensured consistency in our column naming conventions and changed the state names to abbreviations.

# %% [markdown]
# ### B. Data Quality and Consistency

# %% [markdown]
# #### Approach

# %% [markdown]
# We're going to be looking at a few things in terms of data quality and consistency
#
# 1. Checking for null values
# 2. Checking for duplicates
# 3. Checking for mixed-type data

# %% [markdown]
# 1. Checking for null values

# %%
df3.isnull().sum()
# Out:
# user_id           0
# gender            0
# state             0
# age               0
# date_joined       0
# n_dependants      0
# dependants_loc    0
# fam_status        0
# income            0
# dtype: int64

# %% [markdown]
# ##### Observations:

# %% [markdown]
# No missing data observed

# %% [markdown]
# 2. Checking for duplicates

# %%
df_dups = df3[df3.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, n_dependants, dependants_loc, fam_status, income]
# Index: []

# %% [markdown]
# ##### Observations:

# %% [markdown]
# No duplicate rows found

# %% [markdown]
# 3. Checking for mixed-type data

# %%
for col in df3.columns.tolist():
    weird = (df3[[col]].applymap(type) != df3[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df3[weird]) > 0:
        print (col)

# %% [markdown]
# ##### Observations:

# %% [markdown]
# No mixed-type data identified.
#
# Interestingly, when I ran this code on the original data there were over 11,000 mixed-type data points in the first name field, representing around 5.5.% of the data set, but given that name is not important to our statistical analysis we have removed the column.

# %% [markdown]
# ## C. Merging

# %% [markdown]
# Merging our new customers dataset with our existing orders and products dataset

# %%
#import orders and products dataset 
df_merge = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'full_merged5.pkl'))

# %%
#check output
df_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    ... prices    price_range_loc    busiest_days  busiest_period_of_day  \
# 0  ...    9.0  Mid-range product  Regularly busy         Average orders
# 1  ...   12.5  Mid-range product  Regularly busy         Average orders
# 2  ...    4.4  Low-range product  Regularly busy         Average orders
# 3  ...    4.7  Low-range product  Regularly busy         Average orders
# 4  ...    1.0  Low-range product  Regularly busy         Average orders
#
#   max_order  loyalty_flag avg_price  spending_flag order_freq  \
# 0        10  New customer      6.37    Low spender       20.5
# 1        10  New customer      6.37    Low spender       20.5
# 2        10  New customer      6.37    Low spender       20.5
# 3        10  New customer      6.37    Low spender       20.5
# 4        10  New customer      6.37    Low spender       20.5
#
#          order_freq_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
#
# [5 rows x 23 columns]

# %%
df_merge.shape
# Out:
# (32435059, 23)

# %%
df_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243506e+07  3.243506e+07  3.243506e+07        3.243506e+07
# mean   1.710748e+06  1.029372e+05  1.714195e+01        2.738815e+00
# std    9.873006e+05  5.946651e+04  1.753496e+01        2.090051e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711047e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243506e+07              30356957.0  3.243506e+07
# mean        1.342498e+01                     NaN  3.121809e+03
# std         4.246357e+00                     0.0  2.110400e+04
# min         0.000000e+00                     0.0 -3.276800e+04
# 25%         1.000000e+01                     5.0 -1.999900e+04
# 50%         1.300000e+01                     8.0  8.581000e+03
# 75%         1.600000e+01                    15.0  2.161600e+04
# max         2.300000e+01                    30.0  3.276700e+04
#
#        add_to_cart_order     reordered    aisle_id  department_id  \
# count       3.243506e+07  3.243506e+07  32404859.0     32404859.0
# mean        8.351081e+00  5.896955e-01         NaN            NaN
# std         7.126656e+00  4.918889e-01         0.0            0.0
# min         1.000000e+00  0.000000e+00         1.0            1.0
# 25%         3.000000e+00  0.000000e+00        31.0            4.0
# 50%         6.000000e+00  1.000000e+00        83.0            9.0
# 75%         1.100000e+01  1.000000e+00       107.0           16.0
# max         1.450000e+02  1.000000e+00       134.0           21.0
#
#              prices     max_order     avg_price  order_freq
# count  3.240486e+07  3.243506e+07  3.243506e+07  32435059.0
# mean   1.198023e+01  3.305231e+01  1.197850e+01         NaN
# std    4.956554e+02  2.515463e+01  8.321714e+01         0.0
# min    1.000000e+00  3.000000e+00  1.000000e+00         0.0
# 25%    4.200000e+00  1.300000e+01  7.390000e+00         6.0
# 50%    7.400000e+00  2.600000e+01  7.820000e+00         8.0
# 75%    1.130000e+01  4.700000e+01  8.250000e+00        13.0
# max    9.999900e+04  9.900000e+01  2.500542e+04        30.0

# %%
#reminder of our new data set to be merged 
df3.head()
# Out:
#    user_id  gender state  age date_joined  n_dependants  dependants_loc  \
# 0    26711  Female    MO   48  2017-01-01             3  Has dependants
# 1    33890  Female    NM   36  2017-01-01             0   No dependants
# 2    65803    Male    ID   35  2017-01-01             2  Has dependants
# 3   125935  Female    IA   40  2017-01-01             0   No dependants
# 4   130797  Female    MD   26  2017-01-01             1  Has dependants
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %%
df3.shape
# Out:
# (206209, 9)

# %% [markdown]
# To merge our two dataframes, we need to have a common variable. In this case, it is user_id.

# %%
#merging our datasets
df_combo = df_merge.merge(df3, on = ['user_id'])

# %%
df_combo.sample(5)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1996145    1037729    12833            20                   2
# 15429741   1428017    97613             6                   1
# 9844480    1555805    62576             1                   6
# 20392623    779981   129443             6                   6
# 23697594   3164437   150518            28                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 1996145                  17                    11.0       31134
# 15429741                  9                    28.0       23579
# 9844480                  12                     NaN      -20472
# 20392623                 12                    14.0      -27228
# 23697594                 17                    13.0        4399
#
#           add_to_cart_order  reordered _merge  ... order_freq  \
# 1996145                  49          1   both  ...        9.0
# 15429741                  3          0   both  ...       30.0
# 9844480                   4          0   both  ...       30.0
# 20392623                  9          0   both  ...       12.0
# 23697594                  4          1   both  ...       10.0
#
#                 order_freq_flag  gender  state age date_joined n_dependants  \
# 1996145       Frequent customer  Female     OR  70  2018-10-04            2
# 15429741  Non-frequent customer    Male     WI  26  2019-05-18            2
# 9844480   Non-frequent customer    Male     WI  76  2017-04-30            2
# 20392623       Regular customer    Male     CA  38  2019-09-01            3
# 23697594      Frequent customer  Female     KS  41  2017-05-12            0
#
#           dependants_loc fam_status  income
# 1996145   Has dependants    married   34888
# 15429741  Has dependants    married   81621
# 9844480   Has dependants    married  146652
# 20392623  Has dependants    married   54322
# 23697594   No dependants     single  111338
#
# [5 rows x 31 columns]

# %%
df_combo.shape
# Out:
# (32435059, 31)

# %%
#Checking value counts
df_combo['_merge'].value_counts()
# Out:
# both          32435059
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_combo.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243506e+07  3.243506e+07  3.243506e+07        3.243506e+07
# mean   1.710748e+06  1.029372e+05  1.714195e+01        2.738815e+00
# std    9.873006e+05  5.946651e+04  1.753496e+01        2.090051e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711047e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243506e+07              30356957.0  3.243506e+07
# mean        1.342498e+01                     NaN  3.121809e+03
# std         4.246357e+00                     0.0  2.110400e+04
# min         0.000000e+00                     0.0 -3.276800e+04
# 25%         1.000000e+01                     5.0 -1.999900e+04
# 50%         1.300000e+01                     8.0  8.581000e+03
# 75%         1.600000e+01                    15.0  2.161600e+04
# max         2.300000e+01                    30.0  3.276700e+04
#
#        add_to_cart_order     reordered    aisle_id  department_id  \
# count       3.243506e+07  3.243506e+07  32404859.0     32404859.0
# mean        8.351081e+00  5.896955e-01         NaN            NaN
# std         7.126656e+00  4.918889e-01         0.0            0.0
# min         1.000000e+00  0.000000e+00         1.0            1.0
# 25%         3.000000e+00  0.000000e+00        31.0            4.0
# 50%         6.000000e+00  1.000000e+00        83.0            9.0
# 75%         1.100000e+01  1.000000e+00       107.0           16.0
# max         1.450000e+02  1.000000e+00       134.0           21.0
#
#              prices     max_order     avg_price  order_freq           age  \
# count  3.240486e+07  3.243506e+07  3.243506e+07  32435059.0  3.243506e+07
# mean   1.198023e+01  3.305231e+01  1.197850e+01         NaN  4.946512e+01
# std    4.956554e+02  2.515463e+01  8.321714e+01         0.0  1.848555e+01
# min    1.000000e+00  3.000000e+00  1.000000e+00         0.0  1.800000e+01
# 25%    4.200000e+00  1.300000e+01  7.390000e+00         6.0  3.300000e+01
# 50%    7.400000e+00  2.600000e+01  7.820000e+00         8.0  4.900000e+01
# 75%    1.130000e+01  4.700000e+01  8.250000e+00        13.0  6.500000e+01
# max    9.999900e+04  9.900000e+01  2.500542e+04        30.0  8.100000e+01
#
#        n_dependants        income
# count  3.243506e+07  3.243506e+07
# mean   1.501877e+00  9.943550e+04
# std    1.118869e+00  4.305540e+04
# min    0.000000e+00  2.590300e+04
# 25%    1.000000e+00  6.700200e+04
# 50%    2.000000e+00  9.661200e+04
# 75%    3.000000e+00  1.279080e+05
# max    3.000000e+00  5.939010e+05

# %%
#checking on space constraints
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32435059 entries, 0 to 32435058
# Data columns (total 31 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   orders_day_of_week      int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float16
#  6   product_id              int16
#  7   add_to_cart_order       int16
#  8   reordered               int16
#  9   _merge                  category
#  10  product_name            object
#  11  aisle_id                float16
#  12  department_id           float16
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest_days            object
#  16  busiest_period_of_day   object
#  17  max_order               int8
#  18  loyalty_flag            object
#  19  avg_price               float64
#  20  spending_flag           object
#  21  order_freq              float16
#  22  order_freq_flag         object
#  23  gender                  object
#  24  state                   object
#  25  age                     int8
#  26  date_joined             datetime64[ns]
#  27  n_dependants            int16
#  28  dependants_loc          object
#  29  fam_status              object
#  30  income                  int32
# dtypes: category(1), datetime64[ns](1), float16(4), float64(2), int16(4), int32(3), int8(5), object(11)
# memory usage: 4.7+ GB

# %% [markdown]
# ## Export dataframe

# %%
#export to pickle 
df_combo.to_pickle(os.path.join(path, '02_Data','Prepared_data', 'orders_products_all.pkl'))
