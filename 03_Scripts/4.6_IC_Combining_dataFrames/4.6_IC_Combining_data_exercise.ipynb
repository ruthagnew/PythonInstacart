# %% [markdown]
# # Combining Data - Exercise 4.6
#
# ### Combing merged orders with prior orders

# %%
#import libraries
import pandas as pd
import numpy as nm
import os

# %%
#folder path into usable string
path = r'C:\Users\rutha\CareerFoundry\01-23_Instacart_Basket_Analysis'

# %%
#import merged data set
df_ords_combined = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'order_products_combined.pkl'))

# %%
#check the shape of df_ords_combined
df_ords_combined.shape
# Out:
# (32434489, 10)

# %%
df_ords_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_combined.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07        3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01        2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01        2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00        1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# **Observations:** The dataframe is the same shape as before

# %%
#import prods data set
df_prods = pd.read_csv(os.path.join(path, '02_Data', 'Prepared_data', 'products_clean.csv'),index_col=False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#removing unnamed column
df_prods = df_prods.drop(['Unnamed: 0'],axis=1)

# %%
#checking output
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# **Question:** Determine a suitable way to combine df_ords_combined with the products data set.

# %% [markdown]
# **Answer:** Given that we would expect all of the product_id codes in the ords_combined dataframe to map back to the prods dataframe, I am going to use the default merged of outer, combined with the merge() function. This should also allow us to see any instances where product_id don't match, as they would appear as NaN values. It should be in wide-format.

# %%
#merging data sets
df_merged = df_ords_combined.merge(df_prods, on = ['product_id'])

# %% [markdown]
# Confirm the results using a the merge flag

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
#check output
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.describe()

# %% [markdown]
# Export your new merged dataframe to pickle

# %%
#export df_merged
df_merged.to_pickle(os.path.join(path, '02_Data', 'Prepared_data', 'full_merged.pkl'))
